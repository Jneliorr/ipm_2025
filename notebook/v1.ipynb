# %%
import pandas as pd
import os
import duckdb as db
import glob


con = db.connect()

# %%
pasta = r'C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811'
arquivos = glob.glob(os.path.join(pasta, '*Entrada*.xlsx'))

# %%
arquivos
# Out:
# ['C:\\Users\\Jose Nelio\\Documents\\GitHub\\ipm_2025\\data\\efd_base\\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte1_20250811.xlsx',
#  'C:\\Users\\Jose Nelio\\Documents\\GitHub\\ipm_2025\\data\\efd_base\\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte2_20250811.xlsx',
#  'C:\\Users\\Jose Nelio\\Documents\\GitHub\\ipm_2025\\data\\efd_base\\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte3_20250811.xlsx',
#  'C:\\Users\\Jose Nelio\\Documents\\GitHub\\ipm_2025\\data\\efd_base\\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte4_20250811.xlsx',
#  'C:\\Users\\Jose Nelio\\Documents\\GitHub\\ipm_2025\\data\\efd_base\\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte5_20250811.xlsx',
#  'C:\\Users\\Jose Nelio\\Documents\\GitHub\\ipm_2025\\data\\efd_base\\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte6_20250811.xlsx']

# %%
a = 'C:\\Users\\Jose Nelio\\Documents\\GitHub\\ipm_2025\\data\\efd_base\\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte1_20250811.xlsx'

# %%
a.split('_')[-2]
# Out:
# 'parte1'

# %%
dfs = []
for arquivo in arquivos:
    print(f'Lendo: {arquivo}')
    df = pd.read_excel(arquivo)
    df['parte'] = arquivo.split('_')[-2]
    dfs.append(df)
# Out:
# Lendo: C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte1_20250811.xlsx
# c:\Users\Jose Nelio\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Lendo: C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte2_20250811.xlsx
# c:\Users\Jose Nelio\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Lendo: C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte3_20250811.xlsx
# c:\Users\Jose Nelio\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Lendo: C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte4_20250811.xlsx
# c:\Users\Jose Nelio\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Lendo: C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte5_20250811.xlsx
# c:\Users\Jose Nelio\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Lendo: C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte6_20250811.xlsx
# c:\Users\Jose Nelio\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df = pd.read_excel(r'C:\Users\Jose Nelio\Documents\GitHub\ipm_2025\data\efd_base\CIPM_EFD-Base-IPM_2027_AnoBase2025_Projetado_20250811\EFD-Base-Entrada_IPM_2027_AnoBase2025_Provisório_parte3_20250811.xlsx'
                   ,skiprows=1)
# Out:
# c:\Users\Jose Nelio\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#         Inscrição Estadual        CPF/CNPJ  Ano de referência  \
# 0                 14587535  11137051092102               2025
# 1                 14587535  11137051092102               2025
# 2                 14587535  11137051092102               2025
# 3                 14587535  11137051092102               2025
# 4                 14587535  11137051092102               2025
# ...                    ...             ...                ...
# 333104            78198290   8409412000191               2025
# 333105            78198290   8409412000191               2025
# 333106            78198290   8409412000191               2025
# 333107            78198290   8409412000191               2025
# 333108            78198290   8409412000191               2025
#
#         Mês de apuração       Hash do arquivo transmitido  \
# 0                     2  0ABB8048AADA0107B33F39A5E5D11DEF
# 1                     2  0ABB8048AADA0107B33F39A5E5D11DEF
# 2                     2  0ABB8048AADA0107B33F39A5E5D11DEF
# 3                     2  0ABB8048AADA0107B33F39A5E5D11DEF
# 4                     2  0ABB8048AADA0107B33F39A5E5D11DEF
# ...                 ...                               ...
# 333104                6  CEDFE429A26D87EB37717AECC6679629
# 333105                6  CEDFE429A26D87EB37717AECC6679629
# 333106                6  CEDFE429A26D87EB37717AECC6679629
# 333107                6  CEDFE429A26D87EB37717AECC6679629
# 333108                6  CEDFE429A26D87EB37717AECC6679629
#
#        Origem da Informação  Cód. Município Origem D100  CFOP  \
# 0                      C190                         0.0  2102
# 1                      C190                         0.0  2407
# 2                      C190                         0.0  2556
# 3                      C590                         0.0  1253
# 4                      D190                   3304557.0  1353
# ...                     ...                         ...   ...
# 333104                 D190                   4126256.0  2352
# 333105                 D190                   4208203.0  2352
# 333106                 D190                   4206306.0  2352
# 333107                 D190                   2900702.0  2352
# 333108                 D190                   4202909.0  2352
#
#              Valor Operação        Valor BC ICMS Declaração utilizado?  \
# 0                  2.303,98                 0,00                   SIM
# 1                    225,12                 0,00                   SIM
# 2                  7.057,88                 0,00                   SIM
# 3                  1.338,06                 0,00                   SIM
# 4                    243,51                 0,00                   SIM
# ...                     ...                  ...                   ...
# 333104               252,40               248,77                   SIM
# 333105            10.925,54            10.925,54                   SIM
# 333106             1.881,88                 0,00                   SIM
# 333107               194,50               194,50                   SIM
# 333108            49.406,38            49.406,38                   SIM
#
#        Registro utilizado no calculo VA?
# 0                                    SIM
# 1                                    NÃO
# 2                                    NÃO
# 3                                    NÃO
# 4                                    SIM
# ...                                  ...
# 333104                               SIM
# 333105                               SIM
# 333106                               SIM
# 333107                               SIM
# 333108                               SIM
#
# [333109 rows x 12 columns]

# %%
db.sql("""
SELECT 
    "Origem da Informação",
    "Valor Operação"
FROM df
WHERE "Origem da Informação" IN ('C190','C590') AND
"Cód. Município Origem D100" = 29
 """)
# Out:
# ┌──────────────────────┬────────────────┐
# │ Origem da Informação │ Valor Operação │
# │       varchar        │    varchar     │
# ├──────────────────────┴────────────────┤
# │                0 rows                 │
# └───────────────────────────────────────┘
